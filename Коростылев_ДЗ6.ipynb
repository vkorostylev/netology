# %% [markdown]
# # **Задание 1**
#
# Используем файл keywords.csv.
#
# Необходимо написать гео-классификатор, который каждой строке сможет выставить географическую принадлежность определенному региону. Т. е. если поисковый запрос содержит название города региона, то в столбце 'region' пишется название этого региона. Если поисковый запрос не содержит названия города, то ставим 'undefined'.

# %%
import pandas as pd
data=pd.read_csv('keywords.csv')
data.head()
# Out:
#          keyword     shows
# 0             вк  64292779
# 1  одноклассники  63810309
# 2          порно  41747114
# 3           ютуб  39995567
# 4      вконтакте  21014195

# %%
geo_data = {

    'Центр': ['москва', 'тула', 'ярославль'],

    'Северо-Запад': ['петербург', 'псков', 'мурманск'],

    'Дальний Восток': ['владивосток', 'сахалин', 'хабаровск']

}

# %%
def region(word):
    for i,n in geo_data.items():
        g=0
        while g<int(len(word)):
            if word[g] in n:
                return i
            else:
                g=g+1
    return 'undef'

# %%
data['region']=data.apply(lambda x: region((x['keyword'].split(' '))), axis=1)

# %%
data.groupby('region').sum().reset_index().sort_values('shows', ascending=False).head()
# Out:
#            region       shows
# 0           undef  2585922914
# 3           Центр     7532516
# 2    Северо-Запад     2810318
# 1  Дальний Восток     1163771

# %%
data[~data.region.str.contains('undef')]
# Out:
#                                                 keyword   shows  \
# 127                                        авито москва  979292
# 370                            авито ру санкт петербург  425134
# 849                                     авито ярославль  209581
# 1063                                фарпост владивосток  176951
# 1236                               банк санкт петербург  174375
# 1259                                             москва  153050
# 1346                                    санкт петербург  144232
# 1396                                    гисметео москва  140279
# 1482                                   госуслуги москва  133061
# 1579                                         авито тула  126168
# 1682                                      погода москва  151701
# 2153                                        авито псков   98931
# 2175                                     дром хабаровск   98361
# 2398                                     авито мурманск   89787
# ...

# %% [markdown]
# # **Задание 2**
#
# Напишите функцию, которая классифицирует фильмы из материалов занятия по следующим правилам:
#     - оценка 2 и меньше - низкий рейтинг
#     - оценка 4 и меньше - средний рейтинг
#     - оценка 4.5 и 5 - высокий рейтинг
#
# Результат классификации запишите в столбец class

# %%
data2 = pd.read_csv('6/ml-latest-small/ratings.csv')
data2.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182
# 3       1     1129     2.0  1260759185
# 4       1     1172     4.0  1260759205

# %%
#проверяем какие оценки есть в дата сете
data2.groupby('rating').count().reset_index()['rating']
# Out:
# 0    0.5
# 1    1.0
# 2    1.5
# 3    2.0
# 4    2.5
# 5    3.0
# 6    3.5
# 7    4.0
# 8    4.5
# 9    5.0
# Name: rating, dtype: float64

# %%
def rate(point):
    if point <= 2:
        return 'низкий рейтинг'
    elif point <= 4:
        return 'средний рейтинг'
    elif point >4:
        return 'высокий рейтинг'

# %%
rate(0)
# Out:
# 'низкий рейтинг'

# %%
data2['class']=data2.apply(lambda y: rate(y['rating']), axis=1)

# %%
data2
# Out:
#         userId  movieId  rating   timestamp            class
# 0            1       31     2.5  1260759144  средний рейтинг
# 1            1     1029     3.0  1260759179  средний рейтинг
# 2            1     1061     3.0  1260759182  средний рейтинг
# 3            1     1129     2.0  1260759185   низкий рейтинг
# 4            1     1172     4.0  1260759205  средний рейтинг
# 5            1     1263     2.0  1260759151   низкий рейтинг
# 6            1     1287     2.0  1260759187   низкий рейтинг
# 7            1     1293     2.0  1260759148   низкий рейтинг
# 8            1     1339     3.5  1260759125  средний рейтинг
# 9            1     1343     2.0  1260759131   низкий рейтинг
# 10           1     1371     2.5  1260759135  средний рейтинг
# 11           1     1405     1.0  1260759203   низкий рейтинг
# 12           1     1953     4.0  1260759191  средний рейтинг
# 13           1     2105     4.0  1260759139  средний рейтинг
# ...

# %% [markdown]
# # **Задание 3**
#
# Посчитайте среднее значение Lifetime киноманов (пользователи, которые поставили 100 и более рейтингов). Под Lifetime понимается разница между максимальным и минимальным значением timestamp для каждого пользователя. Ответ дайте в днях.

# %%
ratings = pd.read_csv('6/ml-latest-small/ratings.csv')
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182
# 3       1     1129     2.0  1260759185
# 4       1     1172     4.0  1260759205

# %%
grouped = ratings.groupby('userId').count().reset_index()
ratings_filtered = grouped[grouped['timestamp'] >= 100]
ratings_filtered.head()
# Out:
#     userId  movieId  rating  timestamp
# 3        4      204     204        204
# 4        5      100     100        100
# 7        8      116     116        116
# 14      15     1700    1700       1700
# 16      17      363     363        363

# %%
ratings_kinoman=ratings[ratings['userId'].isin(ratings_filtered['userId'].tolist())]

# %%
ratings_kinoman_=(ratings_kinoman
 .groupby('userId')
 .agg(['min', 'max'])
 .reset_index()
 [['userId','timestamp']])

# %%
ratings_kinoman_.head()
# Out:
#   userId   timestamp
#                  min         max
# 0      4   949778714   949982274
# 1      5  1163373044  1163375145
# 2      8  1154389340  1154474527
# 3     15   997937239  1469330735
# 4     17  1127468587  1127476640

# %%
def minus(ma,mi):
    return (int(ma)-int(mi))/60/60/24

# %%
ratings_kinoman_['dif'] = ratings_kinoman_.apply(lambda x: minus(x['timestamp']['max'],x['timestamp']['min']), axis=1)
ratings_kinoman_.head()
# Out:
#   userId   timestamp                      dif
#                  min         max
# 0      4   949778714   949982274     2.356019
# 1      5  1163373044  1163375145     0.024317
# 2      8  1154389340  1154474527     0.985961
# 3     15   997937239  1469330735  5455.943241
# 4     17  1127468587  1127476640     0.093206

# %%
#среднее кол-во дней жизни аккаунта с более 100 отзывов
ratings_kinoman_['dif'].mean()
# Out:
# 455.22857137198986

# %% [markdown]
# # **Задание 4**
#
# Есть мнение, что "раньше снимали настоящее кино, не то что сейчас". Ваша задача проверить это утверждение, используя файлы с рейтингами фильмов из материалов занятия. Т. е. проверить верно ли, что с ростом года выпуска фильма его средний рейтинг становится ниже.
#
# При этом мы не будем затрагивать субьективные факторы выставления этих рейтингов, а пройдемся по следующему алгоритму:
#
# 1. В переменную years запишите список из всех годов с 1950 по 2010.
#
# 2. Напишите функцию production_year, которая каждой строке из названия фильма выставляет год выпуска. Не все названия фильмов содержат год выпуска в одинаковом формате, поэтому используйте следующий алгоритм:
#     - для каждой строки пройдите по всем годам списка years
#     - если номер года присутствует в названии фильма, то функция возвращает этот год как год выпуска
#     - если ни один из номеров года списка years не встретился в названии фильма, то возвращается 1900 год
#
# 3. Запишите год выпуска фильма по алгоритму пункта 2 в новый столбец 'year'
#
# 4. Посчитайте средний рейтинг всех фильмов для каждого значения столбца 'year' и отсортируйте результат по убыванию рейтинга

# %%
movies = pd.read_csv('6/ml-latest-small/movies.csv')
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
years=[]
for i in range(1950,2010):
    years.append(i)

# %%
def production_year(x):
    for a in years:
        if str(a) in str(x):
            return a
    return int('1950')

# %%
production_year('Nerve(2016)')
# Out:
# 1950

# %%
movies['year'] = movies['title'].apply(lambda x: production_year(x))
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres  year
# 0  Adventure|Animation|Children|Comedy|Fantasy  1995
# 1                   Adventure|Children|Fantasy  1995
# 2                               Comedy|Romance  1995
# 3                         Comedy|Drama|Romance  1995
# 4                                       Comedy  1995

# %%
joined = ratings.merge(movies, on='movieId', how='left')
joined.head()
# Out:
#    userId  movieId  rating   timestamp  \
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182
# 3       1     1129     2.0  1260759185
# 4       1     1172     4.0  1260759205
#
#                                             title  \
# 0                          Dangerous Minds (1995)
# 1                                    Dumbo (1941)
# 2                                 Sleepers (1996)
# 3                     Escape from New York (1981)
# 4  Cinema Paradiso (Nuovo cinema Paradiso) (1989)
#
#                              genres  year
# 0                             Drama  1995
# 1  Animation|Children|Drama|Musical  1950
# 2                          Thriller  1996
# 3  Action|Adventure|Sci-Fi|Thriller  1981
# 4                             Drama  1989

# %%
joined.groupby('year').mean()[['rating']].sort_values('rating', ascending=False)
# Out:
#         rating
# year
# 1957  4.014241
# 1972  4.011136
# 1952  4.000000
# 1954  3.994220
# 1951  3.983539
# 1974  3.978704
# 1962  3.952446
# 1977  3.905786
# 1964  3.841492
# 1959  3.841033
# 1958  3.823171
# 1975  3.823077
# 1969  3.817376
# 1967  3.814516
# 1960  3.809211
# 1976  3.806794
# 1973  3.806667
# 1979  3.777966
# 1981  3.758763
# 1953  3.754587
# 1955  3.751724
# 1971  3.748830
# 1968  3.737844
# 1966  3.736726
# 1980  3.708816
# 1963  3.705966
# 1970  3.700000
# 1965  3.678715
# 1961  3.663851
# 1983  3.657635
# 1984  3.651486
# 1982  3.638306
# 1991  3.628265
# 1956  3.617647
# 1987  3.606015
# 1950  3.602036
# 1985  3.588998
# 1988  3.552990
# 1978  3.549003
# 2007  3.548538
# 1994  3.537963
# 1993  3.536664
# 1989  3.534349
# 1986  3.528265
# 2009  3.520378
# 2006  3.511478
# 2008  3.498057
# 2004  3.491490
# 1998  3.472754
# 1995  3.472118
# 1999  3.471692
# 1992  3.466754
# 2001  3.460052
# 2002  3.456297
# 1990  3.449169
# 2005  3.448434
# 2003  3.444777
# ...
