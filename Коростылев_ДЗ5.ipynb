# %% [markdown]
# # **Задание 1**
# Создайте numpy array с элементами от числа N до 0 (например, для N = 10 это будет array([9, 8, 7, 6, 5, 4, 3, 2, 1, 0])).

# %%
import numpy as np
n=int(input('Введите число'))
x = np.arange(0,n)
n=x[::-1]
n
# Out:
# Введите число10
# array([9, 8, 7, 6, 5, 4, 3, 2, 1, 0])

# %% [markdown]
# # **Задание 2**
# Создайте диагональную матрицу с элементами от N до 0. Посчитайте сумму ее значений на диагонали.

# %%
matrix=np.diag(n, k=0)
sum(np.diag(matrix))
# Out:
# 45

# %% [markdown]
# # **Задание 3**
# Скачайте с сайта https://grouplens.org/datasets/movielens/ датасет любого размера. Определите какому фильму было выставлено больше всего оценок 5.0.
#
# Ответ: 318 фильм, 153 оценки 5.0

# %%
import pandas as pd

# %%
data=pd.read_csv('ratings.csv')
data[:3]
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224

# %%
data[data.rating == 5.0 ]['movieId'].value_counts().head()
# Out:
# 318     153
# 296     123
# 356     116
# 2571    109
# 260     104
# Name: movieId, dtype: int64

# %% [markdown]
# # **Задание 4**
# По данным файла power.csv посчитайте суммарное потребление стран Прибалтики (Латвия, Литва и Эстония) категорий 4, 12 и 21 за период с 2005 по 2010 года. Не учитывайте в расчетах отрицательные значения quantity.

# %%
data=pd.read_csv('C:/Users/korostylev.v/Desktop/New folder/5/power.csv')
data.head()
# Out:
#    country  year  quantity  category
# 0  Austria  1996       5.0         1
# 1  Austria  1995      17.0         1
# 2  Belgium  2014       0.0         1
# 3  Belgium  2013       0.0         1
# 4  Belgium  2012      35.0         1

# %% [markdown]
# Кажется, что это можно сделать быстрее и проще, но я написал в лоб.

# %%
data[(data['year']>2005)&((data['category']==4)|(data['category']==12)|(data['category']==21))&(data.quantity >= 0.0)&((data['country']=='Latvia')|(data['country']=='Lithuania')|(data['country']=='Estonia'))]
# Out:
#           country  year  quantity  category
# 10617     Estonia  2008       1.0         4
# 10618     Estonia  2007       0.0         4
# 10619     Estonia  2006       0.0         4
# 11156   Lithuania  2008       1.0         4
# 11157   Lithuania  2007       0.0         4
# 11158   Lithuania  2006       1.0         4
# 12755     Estonia  2008       1.0         4
# 12756     Estonia  2007       0.0         4
# 12757     Estonia  2006       0.0         4
# 13294   Lithuania  2008       1.0         4
# 13295   Lithuania  2007       0.0         4
# 13296   Lithuania  2006       1.0         4
# 14643      Latvia  2014       1.0         4
# 14644      Latvia  2013       0.0         4
# 14645      Latvia  2012       2.0         4
# 14646      Latvia  2011       1.0         4
# 14647      Latvia  2010       0.0         4
# 14648      Latvia  2009       0.0         4
# 14649      Latvia  2008       0.0         4
# 14650      Latvia  2007       0.0         4
# ...

# %% [markdown]
# # Задание 5

# %% [markdown]
# 4x + 2y + z = 4
#
# x + 3y = 12
#
# 5y + 4z = -3

# %%
a = np.array( [ [4, 2, 1], [1, 3, 0],[5,0,4] ] )

# %%
b = np.array( [4, 12, -3] )

# %%
from numpy import linalg
linalg.solve(a, b)
# Out:
# array([-1.56,  4.52,  1.2 ])
